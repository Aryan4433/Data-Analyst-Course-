# %% [markdown]
# # Accenture Internship

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Content= pd.read_csv("Content.csv")

# %%
Reactions=pd.read_csv("Reactions.csv")

# %%
ReactionTypes=pd.read_csv("ReactionTypes.csv")

# %%
Content.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %%
Reactions.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %%
ReactionTypes.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %%
print(Content.info())

print(Reactions.info())

print(ReactionTypes.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Content ID  1000 non-null   object
#  2   User ID     1000 non-null   object
#  3   Type        1000 non-null   object
#  4   Category    1000 non-null   object
#  5   URL         801 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25553 non-null  int64
#  1   Content ID  25553 non-null  object
#  2   User ID     22534 non-null  object
#  3   Type        24573 non-null  object
#  4   Datetime    25553 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 998.3+ KB
# None
# ...

# %%
print(Content.shape)

print(Reactions.shape)

print(ReactionTypes.shape)
# Out:
# (1000, 6)
# (25553, 5)
# (16, 4)

# %%
Content.isnull().sum()
# Out:
# Unnamed: 0      0
# Content ID      0
# User ID         0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %%
Reactions.isnull().sum()
# Out:
# Unnamed: 0       0
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
ReactionTypes.isnull().sum()
# Out:
# Unnamed: 0    0
# Type          0
# Sentiment     0
# Score         0
# dtype: int64

# %%
Content.drop(columns=['URL'],inplace=True)

# %%
Content.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food

# %%
Content = Content.loc[:, ~Content.columns.str.contains('^Unnamed')]

# %%
Content.isnull().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Category      0
# dtype: int64

# %%
Content.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Content ID  1000 non-null   object
#  1   User ID     1000 non-null   object
#  2   Type        1000 non-null   object
#  3   Category    1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
Reactions.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %%
Reactions = Reactions.loc[:, ~Reactions.columns.str.contains('^Unnamed')]

# %%
Reactions['Datetime']=pd.to_datetime(Reactions['Datetime'])

# %%
Reactions['User ID'].mode()
# Out:
# 0    68724f58-bc4d-4ab0-a4e1-60cdd5e95e7d
# 1    c76c3393-88e2-47b0-ac37-dc4f2053f5a5
# dtype: object

# %%
Reactions['User ID'].fillna(Reactions['User ID'].mode()[0],inplace =True)

# %%
Reactions['Type'].mode()
# Out:
# 0    heart
# dtype: object

# %%
Reactions['Type'].fillna(Reactions['Type'].mode()[0],inplace =True)

# %%
Reactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Content ID  25553 non-null  object
#  1   User ID     25553 non-null  object
#  2   Type        25553 non-null  object
#  3   Datetime    25553 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 798.7+ KB

# %%
ReactionTypes.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %%
ReactionTypes = ReactionTypes.loc[:, ~ReactionTypes.columns.str.contains('^Unnamed')]

# %%
ReactionTypes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Type       16 non-null     object
#  1   Sentiment  16 non-null     object
#  2   Score      16 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 512.0+ bytes

# %% [markdown]
# # ------

# %%
Content.head()
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  beb1f34e-7870-46d6-9fc7-2e12eb83ce43
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f  a5c65404-5894-4b87-82f2-d787cbee86b4
# 3  356fff80-da4d-4785-9f43-bc1261031dc6  9fb4ce88-fac1-406c-8544-1a899cee7aaf
# 4  01ab84dd-6364-4236-abbb-3f237db77180  e206e31b-5f85-4964-b6ea-d7ee5324def1
#
#     Type        Category
# 0  photo        Studying
# 1  photo  healthy eating
# 2  photo  healthy eating
# 3  photo      technology
# 4  video            food

# %%
Content.rename(columns={"Type":"Content Type"},inplace=True)

# %%
Content
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID Content Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43        photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4        photo   healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf        photo       technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1        video             food
# ...

# %%
Reactions.head()
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  68724f58-bc4d-4ab0-a4e1-60cdd5e95e7d
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  163daa38-8b77-48c9-9af6-37a6c1447ac2
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
#
#       Type            Datetime
# 0    heart 2021-04-22 15:17:15
# 1  disgust 2020-11-07 09:43:50
# 2  dislike 2021-06-17 12:22:51
# 3   scared 2021-04-18 05:13:58
# 4  disgust 2021-01-06 19:13:01

# %%
Reactions.rename(columns={"Type":"Reaction Type"},inplace=True)

# %%
ReactionTypes.head()
# Out:
#          Type Sentiment  Score
# 0       heart  positive     60
# 1        want  positive     70
# 2     disgust  negative      0
# 3        hate  negative      5
# 4  interested  positive     30

# %%
ReactionTypes.rename(columns={"Type":"Reaction Type"},inplace=True)

# %%
ReactionTypes
# Out:
#    Reaction Type Sentiment  Score
# 0          heart  positive     60
# 1           want  positive     70
# 2        disgust  negative      0
# 3           hate  negative      5
# 4     interested  positive     30
# 5    indifferent   neutral     20
# 6           love  positive     65
# 7     super love  positive     75
# 8        cherish  positive     70
# 9          adore  positive     72
# 10          like  positive     50
# 11       dislike  negative     10
# 12     intrigued  positive     45
# 13       peeking   neutral     35
# 14        scared  negative     15
# 15       worried  negative     12

# %%
Content.drop(columns=['User ID'],inplace=True)

# %%
Reactions.drop(columns=['User ID'],inplace=True)

# %%
Content.head()
# Out:
#                              Content ID Content Type        Category
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo        Studying
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo  healthy eating
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo  healthy eating
# 3  356fff80-da4d-4785-9f43-bc1261031dc6        photo      technology
# 4  01ab84dd-6364-4236-abbb-3f237db77180        video            food

# %%
Content.shape
# Out:
# (1000, 3)

# %%
Reactions.head()
# Out:
#                              Content ID Reaction Type            Datetime
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2         heart 2021-04-22 15:17:15
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust 2020-11-07 09:43:50
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike 2021-06-17 12:22:51
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared 2021-04-18 05:13:58
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust 2021-01-06 19:13:01

# %%
Reactions.shape
# Out:
# (25553, 3)

# %%
ReactionTypes.head()
# Out:
#   Reaction Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30

# %%
ReactionTypes.shape
# Out:
# (16, 3)

# %%
Content
# Out:
#                                Content ID Content Type         Category
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2        photo         Studying
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo   healthy eating
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f        photo   healthy eating
# 3    356fff80-da4d-4785-9f43-bc1261031dc6        photo       technology
# 4    01ab84dd-6364-4236-abbb-3f237db77180        video             food
# ..                                    ...          ...              ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb        video  public speaking
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c          GIF       technology
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b        audio         veganism
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF          culture
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56        audio       technology
#
# [1000 rows x 3 columns]

# %%
Reactions
# Out:
#                                  Content ID Reaction Type            Datetime
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2         heart 2021-04-22 15:17:15
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust 2020-11-07 09:43:50
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike 2021-06-17 12:22:51
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared 2021-04-18 05:13:58
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust 2021-01-06 19:13:01
# ...                                     ...           ...                 ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike 2020-06-27 09:46:48
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued 2021-02-16 17:17:02
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56    interested 2020-09-12 03:54:58
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56       worried 2020-11-04 20:08:31
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish 2021-01-04 04:55:11
#
# [25553 rows x 3 columns]

# %%
ReactionTypes
# Out:
#    Reaction Type Sentiment  Score
# 0          heart  positive     60
# 1           want  positive     70
# 2        disgust  negative      0
# 3           hate  negative      5
# 4     interested  positive     30
# 5    indifferent   neutral     20
# 6           love  positive     65
# 7     super love  positive     75
# 8        cherish  positive     70
# 9          adore  positive     72
# 10          like  positive     50
# 11       dislike  negative     10
# 12     intrigued  positive     45
# 13       peeking   neutral     35
# 14        scared  negative     15
# 15       worried  negative     12

# %%
Reactions=pd.merge(Reactions,Content,on=['Content ID'])

# %%
Reactions
# Out:
#                                  Content ID Reaction Type            Datetime  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2         heart 2021-04-22 15:17:15
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust 2020-11-07 09:43:50
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike 2021-06-17 12:22:51
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared 2021-04-18 05:13:58
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust 2021-01-06 19:13:01
# ...                                     ...           ...                 ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike 2020-06-27 09:46:48
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued 2021-02-16 17:17:02
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56    interested 2020-09-12 03:54:58
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56       worried 2020-11-04 20:08:31
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish 2021-01-04 04:55:11
#
#       Content Type    Category
# ...

# %%
Reactions=pd.merge(Reactions,ReactionTypes,on=['Reaction Type'])

# %%
Reactions
# Out:
#                                  Content ID Reaction Type            Datetime  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2         heart 2021-04-22 15:17:15
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2         heart 2021-04-11 14:29:59
# 2      9f737e0a-3cdd-4d29-9d24-753f4e3be810         heart 2020-12-04 20:00:31
# 3      9f737e0a-3cdd-4d29-9d24-753f4e3be810         heart 2021-06-16 03:02:28
# 4      230c4e4d-70c3-461d-b42c-ec09396efb3f         heart 2021-03-19 08:19:38
# ...                                     ...           ...                 ...
# 25548  435007a5-6261-4d8b-b0a4-55fdc189754b         adore 2020-10-04 22:26:33
# 25549  435007a5-6261-4d8b-b0a4-55fdc189754b         adore 2020-09-18 10:50:50
# 25550  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore 2020-10-31 03:58:44
# 25551  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore 2020-06-25 15:12:29
# 25552  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore 2020-12-17 16:32:57
#
# ...

# %%
Reactions.isnull().sum()
# Out:
# Content ID       0
# Reaction Type    0
# Datetime         0
# Content Type     0
# Category         0
# Sentiment        0
# Score            0
# dtype: int64

# %%
Reactions.to_csv("Reaction.csv", sep=',', index=False, encoding='utf-8')
